# %% [markdown]
# # Dream Team NBA Salary Insights
# Team Members:
# 1. Mary Brown
# 2. Melissa Mason
# 3. Deepen Patel
# 4. Saiteja Venkatapuram
#
# Project Description: We will investigate whether certain factors contributed to a NBA players salary earnings.
#
# Research Question to Answer:
# What attributes contribute to the salaries of NBA players?
# 1. Salary Cap
# 2. Player performance
# 3. Position
# 4. Age
# 5. Social Media

# %%
# run salary cap notebook - Sai
# %run ./"Sai Salary Cap vs Player Salary.ipynb"
# Out:
# SKLEARN PREDICTION - Average Players Salary
# ----------------------------------------
# Intercept: 1.5840278341366365
# Coefficients: [0.02561531 0.01556408]
# ------------------------------------------------------------------------------------------
# New Salary Cap: 108
# New Salary Spent: 120
# Predicted Avg Player Salary: [6.21817086]
# ------------------------------------------------------------------------------------------
#                               OLS Regression Results
# ...
# Dep. Variable:     Avg Player Salary (m)   R-squared:                       0.911
# Model:                               OLS   Adj. R-squared:                  0.900
# Method:                    Least Squares   F-statistic:                     77.19
# Date:                   Wed, 02 Oct 2019   Prob (F-statistic):           1.27e-08
# Time:                           11:20:56   Log-Likelihood:                 3.6590
# No. Observations:                     18   AIC:                            -1.318
# ...

# %%
# run player performance and social media notebook - Melisssa
# %run ./"Melissa Salary Stats Analysis.ipynb"
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MIN'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# ~/Desktop/DataScienceBootCamp/nba-salaries/Melissa Salary Stats Analysis.ipynb in <module>
# ...

# %%
# run player position analysis notebook - Deepen
# %run ./"Deepen Position Vs Salary.ipynb"
# Out:
# ANOVA Test for NBA Positions:
# T-Test for Centers:
# Ttest_1sampResult(statistic=0.9100011078873185, pvalue=0.3661333477105093)
# --------------------------
# T-Test for Power Forward:
# Ttest_1sampResult(statistic=-0.5597835668494989, pvalue=0.5773889161740999)
# --------------------------
# T-Test for Point Guard:
# Ttest_1sampResult(statistic=-0.0008559069003747678, pvalue=0.9993195549489876)
# --------------------------
# T-Test for Small Forward:
# Ttest_1sampResult(statistic=0.5342747981878027, pvalue=0.5950025561511766)
# --------------------------
# T-Test for Shooting Guard:
# Ttest_1sampResult(statistic=-1.0994133004684972, pvalue=0.2755226276532566)
# --------------------------

# %%
# run age analysis notebook - Mary
# %run ./Mary_Age_vs_Salary_Analysis.ipynb
# Out:
# <style>.container { width:100% !important; }</style>
# The correlation between player salary and player age is 0.35
# The correlation between average player salary and player age is 0.5
